# %% [markdown]
# # Explore Issue #3 (F3 - Manual entry if ISBN not found)
#
# Inform the user if the book has not been found with the ISBN and let the user enter data manually.
#
# 1. Clear interface to inform the user
# 2. Input validation with required fields (Name, Creator)
# 3. Allow filling optional fields : Category, Decision (To give, to trash, to sell, to keep, pending), Location
# 4. Book successfully appended to the temporary database after submission
# 5. Confirmation with a success message

# %% [markdown]
# ### A - Interface
#
# Call the file app.py with the streamlit code that generates the interface

# %%
# !py -m streamlit run app.py
# Out:
# ^C

# %% [markdown]
# ### B - Input validation

# %% [markdown]
# On field completion, display warning if :
# - Cost = 0 € to make sure the object has been given
# - Cost too high (for books > 100 €)
#
# On click, display errors altogether for required fields so if :
# - No object selected
# - No name given for the object
# - No cost filled

# %% [markdown]
# #### C - Dictionary
#
# Store each field in a dictionary

# %% [markdown]
# #### Conclusions
#
# ### Conclusion
#
# - **Objective Achieved:** Successfully created the form to be filled by the user to add an object to the inventory, with Streamlit
#     - Implemented clean and user-friendly `selectbox` fields without default values (`index=None`) to force explicit choices.
#     - Developed a robust "error buffer" architecture to accumulate and display all required field validation errors simultaneously upon form submission.
#     - Created contextual UX triggers (warnings for €0 items and high-cost items) and refined terminology (changed "Creator" to "Author or Brand").
#     - Modeled the final form data into a structured Python dictionary ready for database integration.
# - **Strategy:** Form designed with Streamlit
# - **Next Steps - Enhancement:**
#     - Dynamic label for author/brand based on item type
#     - Allow users to pre-define categories per item type for the select box
#     - Allow users to pre-define storage location for the select box
#     - Set maximum cost thresholds per item type to trigger warnings
#     - Improve form layout using columns
